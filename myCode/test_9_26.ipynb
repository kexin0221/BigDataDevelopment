# %% [markdown]
# ## Exercise01

# %%
from nturl2path import url2pathname
from tarfile import data_filter

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.figure import figaspect

from Lesson02.Activity01 import column_names
from scipy.cluster.hierarchy import weighted
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 import matplotlib.pyplot as plt
#       6 from matplotlib.figure import figaspect
# ----> 8 from Lesson02.Activity01 import column_names
#       9 from scipy.cluster.hierarchy import weighted
#
# ModuleNotFoundError: No module named 'Lesson02'

# %%
x = np.linspace(-50, 50, 100)
y = np.power(x, 2)

# %%
plt.plot(x, y)

# %%
y_hat = np.power(x, 3)
plt.plot(x, y_hat)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Exercise02

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 100, 500)
y = np.sin(2*np.pi*x/100) #sin(2πx/100)
ax.plot(x, y)

# %% [markdown]
# ## Activity01

# %%
import pandas as pd

#url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
url = "../Lesson02/Dataset/auto-mpg.data"
df = pd.read_csv(url, sep='\s+')
df.head()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_62424\1806791427.py:5: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(url, sep='\s+')
#    18.0  8  307.0  130.0   3504.  12.0  70  1 chevrolet chevelle malibu
# 0  15.0  8  350.0  165.0  3693.0  11.5  70  1         buick skylark 320
# 1  18.0  8  318.0  150.0  3436.0  11.0  70  1        plymouth satellite
# 2  16.0  8  304.0  150.0  3433.0  12.0  70  1             amc rebel sst
# 3  17.0  8  302.0  140.0  3449.0  10.5  70  1               ford torino
# 4  15.0  8  429.0  198.0  4341.0  10.0  70  1          ford galaxie 500

# %%
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower',
                'weight', 'acceleration', 'year', 'origin', 'name']
df.columns = column_names
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  15.0          8         350.0      165.0  3693.0          11.5    70
# 1  18.0          8         318.0      150.0  3436.0          11.0    70
# 2  16.0          8         304.0      150.0  3433.0          12.0    70
# 3  17.0          8         302.0      140.0  3449.0          10.5    70
# 4  15.0          8         429.0      198.0  4341.0          10.0    70
#
#    origin                name
# 0       1   buick skylark 320
# 1       1  plymouth satellite
# 2       1       amc rebel sst
# 3       1         ford torino
# 4       1    ford galaxie 500

# %%
import numpy as np
df.loc[df.horsepower == '?', 'horsepower'] = np.nan
df['horsepower'] = pd.to_numeric(df['horsepower'])
df['full_date'] = pd.to_datetime(df.year, format='%y')
df['year'] = df['full_date'].dt.year
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  15.0          8         350.0       165.0  3693.0          11.5  1970
# 1  18.0          8         318.0       150.0  3436.0          11.0  1970
# 2  16.0          8         304.0       150.0  3433.0          12.0  1970
# 3  17.0          8         302.0       140.0  3449.0          10.5  1970
# 4  15.0          8         429.0       198.0  4341.0          10.0  1970
#
#    origin                name  full_date
# 0       1   buick skylark 320 1970-01-01
# 1       1  plymouth satellite 1970-01-01
# 2       1       amc rebel sst 1970-01-01
# 3       1         ford torino 1970-01-01
# 4       1    ford galaxie 500 1970-01-01

# %%
df.dtypes
# Out:
# mpg                    float64
# cylinders                int64
# displacement           float64
# horsepower             float64
# weight                 float64
# acceleration           float64
# year                     int32
# origin                   int64
# name                    object
# full_date       datetime64[ns]
# dtype: object

# %%
df.groupby('year')['horsepower'].mean().plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ## Activity02

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

url = "../Lesson02/Dataset/auto-mpg.data"
df = pd.read_csv(url,sep='\s+')
df.head()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_62424\3587724109.py:6: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(url,sep='\s+')
#    18.0  8  307.0  130.0   3504.  12.0  70  1 chevrolet chevelle malibu
# 0  15.0  8  350.0  165.0  3693.0  11.5  70  1         buick skylark 320
# 1  18.0  8  318.0  150.0  3436.0  11.0  70  1        plymouth satellite
# 2  16.0  8  304.0  150.0  3433.0  12.0  70  1             amc rebel sst
# 3  17.0  8  302.0  140.0  3449.0  10.5  70  1               ford torino
# 4  15.0  8  429.0  198.0  4341.0  10.0  70  1          ford galaxie 500

# %%
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower',
                'weight', 'acceleration', 'year', 'origin', 'name']
df.columns = column_names
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  15.0          8         350.0      165.0  3693.0          11.5    70
# 1  18.0          8         318.0      150.0  3436.0          11.0    70
# 2  16.0          8         304.0      150.0  3433.0          12.0    70
# 3  17.0          8         302.0      140.0  3449.0          10.5    70
# 4  15.0          8         429.0      198.0  4341.0          10.0    70
#
#    origin                name
# 0       1   buick skylark 320
# 1       1  plymouth satellite
# 2       1       amc rebel sst
# 3       1         ford torino
# 4       1    ford galaxie 500

# %%
fig, ax = plt.subplots()
ax.scatter(x = df['horsepower'], y = df['weight'])
