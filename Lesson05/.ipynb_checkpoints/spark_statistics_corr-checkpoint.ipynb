# %%
# Import PySpark
import pyspark
from pyspark.sql import SparkSession

#Create SparkSession
spark = SparkSession.builder \
                    .master("local[1]") \
                    .appName("SparkByExamples.com") \
                    .getOrCreate()
sc = spark.sparkContext

# %%
seriesX = sc.parallelize([1.0, 2.0, 3.0, 3.0, 5.0])  # a series
# seriesY must have the same number of partitions and cardinality as seriesX
seriesY = sc.parallelize([11.0, 22.0, 33.0, 33.0, 555.0])

# %%
from pyspark.mllib.stat import Statistics

# %%
# Compute the correlation using Pearson's method. Enter "spearman" for Spearman's method.
# If a method is not specified, Pearson's method will be used by default.
print("Correlation is: " + str(Statistics.corr(seriesX, seriesY, method="pearson")))
# Out:
# Correlation is: 0.8500286768773004

# %%
import numpy as np
data = sc.parallelize(
    [np.array([1.0, 10.0, 100.0]), np.array([2.0, 20.0, 200.0]), np.array([5.0, 33.0, 366.0])]
)  # an RDD of Vectors

# %%
# calculate the correlation matrix using Pearson's method. Use "spearman" for Spearman's method.
# If a method is not specified, Pearson's method will be used by default.
print(Statistics.corr(data, method="pearson"))
# Out:
# [[1.         0.97888347 0.99038957]
#  [0.97888347 1.         0.99774832]
#  [0.99038957 0.99774832 1.        ]]

# %%
df = spark.read.csv("file:///D:/Big-Data-Science/Big-Data-Analysis-with-Python-master/Lesson05/iris.csv", \
                    header = True)

# %%
df.show(5)
# Out:
# +------------+-----------+------------+-----------+-------+
# |sepal_length|sepal_width|petal_length|petal_width|species|
# +------------+-----------+------------+-----------+-------+
# |         5.1|        3.5|         1.4|        0.2| setosa|
# |         4.9|          3|         1.4|        0.2| setosa|
# |         4.7|        3.2|         1.3|        0.2| setosa|
# |         4.6|        3.1|         1.5|        0.2| setosa|
# |           5|        3.6|         1.4|        0.2| setosa|
# +------------+-----------+------------+-----------+-------+
# only showing top 5 rows

# %%
sel_cols = ['sepal_length','sepal_width','petal_length','petal_width']
data = df[sel_cols].rdd.map(lambda row: row[0:])

# %%
correlation_matrix = Statistics.corr(data, method="pearson") #or:"spearman"

# %%
import pandas as pd
correlation_df = pd.DataFrame(correlation_matrix)

# %%
correlation_df.index, correlation_df.columns = df[sel_cols].columns, df[sel_cols].columns

# %%
correlation_df
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000
