# %% [markdown]
# ## Exercise 3: Data selection and the .loc method
#
# Let's select some data with the numpy notation and use the .loc method. We will use the the RadNet Laboratory Analysis, from the U.S. Environmental Protection Agency, located [here](https://opendata.socrata.com/api/views/cf4r-dfwe/). This dataset describes the radioactive content collected by the USPA in different cities in the US, for different radionuclides.

# %%
import numpy as np
import pandas as pd

# %%
url = "https://opendata.socrata.com/api/views/cf4r-dfwe/rows.csv?accessType=DOWNLOAD"

# %%
df = pd.read_csv(url)

# %%
df = pd.read_csv("D:\Big Data Science\Big-Data-Analysis-with-Python\Lesson01\RadNet_Laboratory_Analysis.csv")

# %%
df.head()
# Out:
#   State Location Date Posted Date Collected Sample Type    Unit      Ba-140  \
# 0    ID    Boise  03/30/2011     03/23/2011  Air Filter  pCi/m3  Non-detect
# 1    ID    Boise  03/30/2011     03/23/2011  Air Filter  pCi/m3  Non-detect
# 2    AK   Juneau  03/30/2011     03/23/2011  Air Filter  pCi/m3  Non-detect
# 3    AK     Nome  03/30/2011     03/22/2011  Air Filter  pCi/m3  Non-detect
# 4    AK     Nome  03/30/2011     03/23/2011  Air Filter  pCi/m3  Non-detect
#
#         Co-60      Cs-134 Cs-136      Cs-137  I-131       I-132       I-133  \
# 0  Non-detect  Non-detect    NaN  Non-detect  0.088  Non-detect  Non-detect
# 1  Non-detect  Non-detect    NaN  Non-detect  0.055  Non-detect  Non-detect
# 2  Non-detect      0.0057    NaN      0.0074  0.067  Non-detect  Non-detect
# 3  Non-detect  Non-detect    NaN  Non-detect  0.096  Non-detect  Non-detect
# 4  Non-detect  Non-detect    NaN  Non-detect   0.22  Non-detect  Non-detect
#
#   Te-129 Te-129m      Te-132
# 0    NaN     NaN  Non-detect
# 1    NaN     NaN  Non-detect
# 2    NaN     NaN      0.0043
# 3    NaN     NaN  Non-detect
# 4    NaN     NaN  Non-detect

# %%
df[1:3]
# Out:
#   State Location Date Posted Date Collected Sample Type    Unit      Ba-140  \
# 1    ID    Boise  03/30/2011     03/23/2011  Air Filter  pCi/m3  Non-detect
# 2    AK   Juneau  03/30/2011     03/23/2011  Air Filter  pCi/m3  Non-detect
#
#         Co-60      Cs-134 Cs-136      Cs-137  I-131       I-132       I-133  \
# 1  Non-detect  Non-detect    NaN  Non-detect  0.055  Non-detect  Non-detect
# 2  Non-detect      0.0057    NaN      0.0074  0.067  Non-detect  Non-detect
#
#   Te-129 Te-129m      Te-132
# 1    NaN     NaN  Non-detect
# 2    NaN     NaN      0.0043

# %%
df['State']
# Out:
# 0      ID
# 1      ID
# 2      AK
# 3      AK
# 4      AK
#        ..
# 601    CA
# 602    CA
# 603    UT
# 604    UT
# 605    NY
# Name: State, Length: 606, dtype: object

# %% [markdown]
# First, select the column "State":

# %%
df['State'].head()
# Out:
# 0    ID
# 1    ID
# 2    AK
# 3    AK
# 4    AK
# Name: State, dtype: object

# %% [markdown]
# To filter based on the value of the data, use the comparison with filter:

# %%
df[df.State == "MN"]
# Out:
#     State   Location Date Posted Date Collected     Sample Type   Unit  \
# 367    MN   St. Paul  04/08/2011     03/28/2011  Drinking Water  pCi/l
# 368    MN   St. Paul  04/22/2011     04/13/2011  Drinking Water  pCi/l
# 380    MN      Welch  04/08/2011     03/29/2011  Drinking Water  pCi/l
# 381    MN      Welch  06/01/2011     04/14/2011  Drinking Water  pCi/l
# 555    MN   St. Paul  04/04/2011     03/22/2011   Precipitation  pCi/l
# 556    MN   St. Paul  04/10/2011     03/29/2011   Precipitation  pCi/l
# 557    MN      Welch  04/04/2011     03/17/2011   Precipitation  pCi/l
# 558    MN  Welch/510  04/13/2011     04/04/2011   Precipitation  pCi/l
#
#          Ba-140       Co-60      Cs-134      Cs-136      Cs-137       I-131  \
# 367  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 368  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        0.16
# 380  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 381  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 555  Non-detect  Non-detect  Non-detect         NaN  Non-detect        32.3
# 556  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect          16
# 557  Non-detect  Non-detect  Non-detect         NaN  Non-detect  Non-detect
# 558  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect         9.1
#
#           I-132       I-133      Te-129     Te-129m      Te-132
# 367  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 368  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 380  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 381  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 555  Non-detect  Non-detect         NaN         NaN  Non-detect
# 556  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 557  Non-detect  Non-detect         NaN         NaN  Non-detect
# 558  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect

# %%
df[(df.State == "AK") & (df.Location == "Nome")]
# Out:
#     State Location Date Posted Date Collected    Sample Type    Unit  \
# 3      AK     Nome  03/30/2011     03/22/2011     Air Filter  pCi/m3
# 4      AK     Nome  03/30/2011     03/23/2011     Air Filter  pCi/m3
# 5      AK     Nome  03/30/2011     03/23/2011     Air Filter  pCi/m3
# 6      AK     Nome  04/04/2011     03/24/2011     Air Filter  pCi/m3
# 7      AK     Nome  04/04/2011     03/24/2011     Air Filter  pCi/m3
# 18     AK     Nome  03/30/2011     03/22/2011  Air Cartridge  pCi/m3
# 19     AK     Nome  03/30/2011     03/23/2011  Air Cartridge  pCi/m3
# 133    AK     Nome  03/30/2011     03/20/2011  Air Cartridge  pCi/m3
# 134    AK     Nome  03/30/2011     03/21/2011  Air Cartridge  pCi/m3
# 135    AK     Nome  04/04/2011     03/24/2011  Air Cartridge  pCi/m3
# 136    AK     Nome  04/08/2011     03/25/2011  Air Cartridge  pCi/m3
# 137    AK     Nome  04/08/2011     03/26/2011  Air Cartridge  pCi/m3
# 138    AK     Nome  04/08/2011     03/27/2011  Air Cartridge  pCi/m3
# 139    AK     Nome  04/10/2011     03/28/2011  Air Cartridge  pCi/m3
# 140    AK     Nome  04/08/2011     03/29/2011  Air Cartridge  pCi/m3
# 141    AK     Nome  04/08/2011     03/30/2011  Air Cartridge  pCi/m3
# 142    AK     Nome  04/10/2011     03/31/2011  Air Cartridge  pCi/m3
# 143    AK     Nome  04/10/2011     04/01/2011  Air Cartridge  pCi/m3
# 144    AK     Nome  04/10/2011     04/02/2011  Air Cartridge  pCi/m3
# 145    AK     Nome  04/10/2011     04/03/2011  Air Cartridge  pCi/m3
# 146    AK     Nome  04/10/2011     04/04/2011  Air Cartridge  pCi/m3
# 147    AK     Nome  04/10/2011     04/05/2011  Air Cartridge  pCi/m3
# 149    AK     Nome  04/10/2011     04/05/2011  Air Cartridge  pCi/m3
# 207    AK     Nome  03/30/2011     03/21/2011     Air Filter  pCi/m3
# 208    AK     Nome  03/30/2011     03/22/2011     Air Filter  pCi/m3
#
#          Ba-140       Co-60      Cs-134      Cs-136      Cs-137       I-131  \
# 3    Non-detect  Non-detect  Non-detect         NaN  Non-detect       0.096
# 4    Non-detect  Non-detect  Non-detect         NaN  Non-detect        0.22
# 5    Non-detect  Non-detect       0.016         NaN       0.023         0.2
# 6    Non-detect  Non-detect        0.14  Non-detect        0.12        0.43
# 7    Non-detect  Non-detect         0.1       0.012        0.13        0.39
# 18   Non-detect  Non-detect  Non-detect         NaN  Non-detect        0.34
# 19   Non-detect  Non-detect  Non-detect         NaN  Non-detect        0.78
# 133  Non-detect  Non-detect  Non-detect         NaN  Non-detect        0.11
# 134  Non-detect  Non-detect  Non-detect         NaN  Non-detect        0.41
# 135  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        1.46
# 136  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        0.26
# 137  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        0.46
# 138  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        0.36
# 139  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        0.23
# 140  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        0.36
# 141  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        0.17
# 142  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect       0.061
# 143  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        0.05
# 144  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect       0.056
# 145  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect       0.089
# 146  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect       0.086
# 147  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        0.14
# 149  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 207  Non-detect  Non-detect  Non-detect         NaN       0.015       0.069
# 208  Non-detect  Non-detect  Non-detect         NaN  Non-detect       0.068
#
#           I-132       I-133      Te-129     Te-129m      Te-132
# 3    Non-detect  Non-detect         NaN         NaN  Non-detect
# 4    Non-detect  Non-detect         NaN         NaN  Non-detect
# 5         0.019  Non-detect         NaN         NaN       0.027
# 6         0.094  Non-detect  Non-detect  Non-detect        0.14
# 7         0.076  Non-detect        0.12       0.061        0.12
# 18   Non-detect  Non-detect         NaN         NaN  Non-detect
# 19   Non-detect  Non-detect         NaN         NaN  Non-detect
# 133  Non-detect  Non-detect         NaN         NaN  Non-detect
# 134  Non-detect  Non-detect         NaN         NaN  Non-detect
# 135  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 136  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 137  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 138  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 139  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 140  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 141  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 142  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 143  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 144  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 145  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 146  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 147  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 149  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 207  Non-detect  Non-detect         NaN         NaN  Non-detect
# 208  Non-detect  Non-detect         NaN         NaN  Non-detect

# %% [markdown]
# More than one condition can be applied at the same time:

# %%
df[(df.State == 'CA') & (df['Sample Type'] == 'Drinking Water')]
# Out:
#     State      Location Date Posted Date Collected     Sample Type   Unit  \
# 305    CA   Los Angeles  04/10/2011     04/04/2011  Drinking Water  pCi/l
# 306    CA  Los Angeles   06/01/2011     04/12/2011  Drinking Water  pCi/l
# 356    CA      Richmond  04/09/2011     03/29/2011  Drinking Water  pCi/l
# 357    CA      Richmond  06/01/2011     04/13/2011  Drinking Water  pCi/l
#
#          Ba-140       Co-60      Cs-134      Cs-136      Cs-137       I-131  \
# 305  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        0.39
# 306  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        0.18
# 356  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 357  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
#
#           I-132       I-133      Te-129     Te-129m      Te-132
# 305  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 306  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 356  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 357  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect

# %% [markdown]
# Now select the MN state and the I-131 radionuclide:

# %%
df[(df.State == "MN") ]["I-131"]
# Out:
# 367    Non-detect
# 368          0.16
# 380    Non-detect
# 381    Non-detect
# 555          32.3
# 556            16
# 557    Non-detect
# 558           9.1
# Name: I-131, dtype: object

# %%
df.loc[df.State == "MN", "I-131"]
# Out:
# 367    Non-detect
# 368          0.16
# 380    Non-detect
# 381    Non-detect
# 555          32.3
# 556            16
# 557    Non-detect
# 558           9.1
# Name: I-131, dtype: object

# %% [markdown]
# Another common approach is the use of the method `.loc`:
#
# ```
# df.loc[<row selection>, <column selection>]
# ```

# %%
df.loc[df.State == "MN", "I-131"]
# Out:
# 367    Non-detect
# 368          0.16
# 380    Non-detect
# 381    Non-detect
# 555          32.3
# 556            16
# 557    Non-detect
# 558           9.1
# Name: I-131, dtype: object

# %% [markdown]
# Note that, differently from the results above, the result of the loc filter is a Series and not a DataFrame. This depends on the operation and selection done on the DataFrame and not is caused only by loc: as the DataFrame can be understood as a 2D combination of Series, a selection of one column will return a Series.

# %%
df[['I-132']].head()
# Out:
#         I-132
# 0  Non-detect
# 1  Non-detect
# 2  Non-detect
# 3  Non-detect
# 4  Non-detect
