# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
print("hello world!")
# Out:
# hello world!

# %% [markdown]
# ## Exercise 1: Interacting with the Python Shell Using the IPython Commands

# %%
import numpy as np
vec = np.random.randint(0, 100, size=5)
print(vec)
# Out:
# [ 2 73 50 57 33]

# %%
for j in np.arange(1, vec.size):
    v = vec[j]
    i = j
    while i > 0 and vec[i-1] > v:
        vec[i] = vec[i-1]
        i = i - 1
        print(vec)
    vec[i] = v
    print(vec)
print(vec)
# Out:
# [ 2 73 50 57 33]
# [ 2 73 73 57 33]
# [ 2 50 73 57 33]
# [ 2 50 73 73 33]
# [ 2 50 57 73 33]
# [ 2 50 57 73 73]
# [ 2 50 57 57 73]
# [ 2 50 50 57 73]
# [ 2 33 50 57 73]
# [ 2 33 50 57 73]

# %% [markdown]
# ## Exercise 2: Getting Started with the Jupyter Notebook

# %%
x = 2
print(x*2)
# Out:
# 4

# %%
def mean(a,b):
       return (a+b)/2

# %%
mean(10,20)
# Out:
# 15.0

# %%
# Latex for formula
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-2, 2, 0.1)  # 0.1是步长
y = x**2 + x + 2 * np.abs(x)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(0, 0, c='red')   # c是color
plt.title("$y = x^2 + x + 2|x|$")
# Out:
# Text(0.5, 1.0, '$y = x^2 + x + 2|x|$')

# %%
# load in video and display  （animation_2.mp4 or animation_7.mp4）
from IPython.display import HTML
HTML("""
  <video width="700" height="400" controls loop>
  <source src="videos/animation_7.mp4" type="video/mp4">
  </video>
""")
# Out:
#   <video width="700" height="400" controls loop>
#   <source src="videos/animation_7.mp4" type="video/mp4">
#   </video>

# %% [markdown]
# ## Exercise 3: Reading Data with Pandas

# %%
import pandas as pd
df = pd.read_csv("Dataset/imports-85.csv")
df.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
df[0:5]
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Exercise 4: Data Selection and the .loc Method

# %%
import numpy as np
import pandas as pd

# %%
url = "Dataset/RadNet_Laboratory_Analysis.csv"
df = pd.read_csv(url)

# %%
df['State'].head()  # 默认前五行
# Out:
# 0    ID
# 1    ID
# 2    AK
# 3    AK
# 4    AK
# Name: State, dtype: object

# %%
df[df.State == "MN"]
# Out:
#     State   Location Date Posted Date Collected     Sample Type   Unit  \
# 367    MN   St. Paul  04/08/2011     03/28/2011  Drinking Water  pCi/l
# 368    MN   St. Paul  04/22/2011     04/13/2011  Drinking Water  pCi/l
# 380    MN      Welch  04/08/2011     03/29/2011  Drinking Water  pCi/l
# 381    MN      Welch  06/01/2011     04/14/2011  Drinking Water  pCi/l
# 555    MN   St. Paul  04/04/2011     03/22/2011   Precipitation  pCi/l
# 556    MN   St. Paul  04/10/2011     03/29/2011   Precipitation  pCi/l
# 557    MN      Welch  04/04/2011     03/17/2011   Precipitation  pCi/l
# 558    MN  Welch/510  04/13/2011     04/04/2011   Precipitation  pCi/l
#
#          Ba-140       Co-60      Cs-134      Cs-136      Cs-137       I-131  \
# 367  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 368  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        0.16
# 380  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# ...

# %%
df[(df.State == 'CA') & (df['Sample Type'] == 'Drinking Water')]
# Out:
#     State      Location Date Posted Date Collected     Sample Type   Unit  \
# 305    CA   Los Angeles  04/10/2011     04/04/2011  Drinking Water  pCi/l
# 306    CA  Los Angeles   06/01/2011     04/12/2011  Drinking Water  pCi/l
# 356    CA      Richmond  04/09/2011     03/29/2011  Drinking Water  pCi/l
# 357    CA      Richmond  06/01/2011     04/13/2011  Drinking Water  pCi/l
#
#          Ba-140       Co-60      Cs-134      Cs-136      Cs-137       I-131  \
# 305  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        0.39
# 306  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect        0.18
# 356  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 357  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
#
#           I-132       I-133      Te-129     Te-129m      Te-132
# 305  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# 306  Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# ...

# %%
df[(df.State == "MN") ]["I-131"] # return series
#type(df[(df.State == "MN") ]["I-131"]) # return dataframe
# Out:
# 367    Non-detect
# 368          0.16
# 380    Non-detect
# 381    Non-detect
# 555          32.3
# 556            16
# 557    Non-detect
# 558           9.1
# Name: I-131, dtype: object

# %%
df.loc[df.State == "MN", "I-131"] # return series
# Out:
# 367    Non-detect
# 368          0.16
# 380    Non-detect
# 381    Non-detect
# 555          32.3
# 556            16
# 557    Non-detect
# 558           9.1
# Name: I-131, dtype: object

# %%
df[['I-132']].head()  # return dataframe
# Out:
#         I-132
# 0  Non-detect
# 1  Non-detect
# 2  Non-detect
# 3  Non-detect
# 4  Non-detect

# %%
df.iloc[1:3,7] # return series
# Out:
# 1    Non-detect
# 2    Non-detect
# Name: Co-60, dtype: object

# %%
df.iloc[1:3,[7]] # return dataframe
# Out:
#         Co-60
# 1  Non-detect
# 2  Non-detect

# %% [markdown]
# ## Exercise 5: Exploring Data Types

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "Dataset/RadNet_Laboratory_Analysis.csv"
df = pd.read_csv(url)

# %%
df.dtypes
# Out:
# State             object
# Location          object
# Date Posted       object
# Date Collected    object
# Sample Type       object
# Unit              object
# Ba-140            object
# Co-60             object
# Cs-134            object
# Cs-136            object
# Cs-137            object
# I-131             object
# I-132             object
# I-133             object
# Te-129            object
# Te-129m           object
# Te-132            object
# dtype: object

# %%
df['Date Posted'] = pd.to_datetime(df['Date Posted'])
df['Date Collected'] = pd.to_datetime(df['Date Collected'])

# %%
columns = df.columns
id_cols = ['State', 'Location', "Date Posted", 'Date Collected', 'Sample Type', 'Unit']
columns = list(set(columns) - set(id_cols))
columns
# Out:
# ['Te-132',
#  'Te-129',
#  'Co-60',
#  'Cs-137',
#  'Ba-140',
#  'I-132',
#  'Te-129m',
#  'I-131',
#  'I-133',
#  'Cs-134',
#  'Cs-136']

# %%
df['Cs-134'] = df['Cs-134'].apply(lambda x: np.nan if x == "Non-detect" else x)
df.loc[:, columns] = df.loc[:, columns].map(lambda x: np.nan if x == 'Non-detect' else x)
df.loc[:, columns] = df.loc[:, columns].map(lambda x: np.nan if x == 'ND' else x)

# %%
for col in columns:
    df[col] = pd.to_numeric(df[col])

# %%
df.dtypes
# Out:
# State                     object
# Location                  object
# Date Posted       datetime64[ns]
# Date Collected    datetime64[ns]
# Sample Type               object
# Unit                      object
# Ba-140                   float64
# Co-60                    float64
# Cs-134                   float64
# Cs-136                   float64
# Cs-137                   float64
# I-131                    float64
# I-132                    float64
# I-133                    float64
# Te-129                   float64
# Te-129m                  float64
# Te-132                   float64
# dtype: object

# %%
df['State'] = df['State'].astype('category')
df['Location'] = df['Location'].astype('category')
df['Unit'] = df['Unit'].astype('category')
df['Sample Type'] = df['Sample Type'].astype('category')

# %%
df.dtypes
# Out:
# State                   category
# Location                category
# Date Posted       datetime64[ns]
# Date Collected    datetime64[ns]
# Sample Type             category
# Unit                    category
# Ba-140                   float64
# Co-60                    float64
# Cs-134                   float64
# Cs-136                   float64
# Cs-137                   float64
# I-131                    float64
# I-132                    float64
# I-133                    float64
# Te-129                   float64
# Te-129m                  float64
# Te-132                   float64
# dtype: object

# %% [markdown]
# ## Exercise 7: Exporting Data in Different Formats

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("RadNet_Laboratory_Analysis.csv")
df.head()
# Out:
#   State Location Date Posted Date Collected Sample Type    Unit  Ba-140  \
# 0    ID    Boise  03/30/2011     03/23/2011  Air Filter  pCi/m3     0.0
# 1    ID    Boise  03/30/2011     03/23/2011  Air Filter  pCi/m3     0.0
# 2    AK   Juneau  03/30/2011     03/23/2011  Air Filter  pCi/m3     0.0
# 3    AK     Nome  03/30/2011     03/22/2011  Air Filter  pCi/m3     0.0
# 4    AK     Nome  03/30/2011     03/23/2011  Air Filter  pCi/m3     0.0
#
#    Co-60  Cs-134  Cs-136  Cs-137  I-131  I-132  I-133  Te-129  Te-129m  \
# 0    0.0       0     NaN       0      0      0    0.0     NaN      NaN
# 1    0.0       0     NaN       0      0      0    0.0     NaN      NaN
# 2    0.0       0     NaN       0      0      0    0.0     NaN      NaN
# 3    0.0       0     NaN       0      0      0    0.0     NaN      NaN
# 4    0.0       0     NaN       0      0      0    0.0     NaN      NaN
#
#    Te-132  Ba-140.1
# 0       0       NaN
# 1       0       NaN
# 2       0       NaN
# ...

# %%
columns = df.columns
id_cols = ['State', 'Location', "Date Posted", 'Date Collected', 'Sample Type', 'Unit']
columns = list(set(columns) - set(id_cols))
columns
# Out:
# ['Te-132',
#  'Te-129',
#  'Co-60',
#  'Cs-137',
#  'Ba-140',
#  'I-132',
#  'Te-129m',
#  'Ba-140.1',
#  'I-131',
#  'I-133',
#  'Cs-134',
#  'Cs-136']

# %%
df['Cs-134'] = df['Cs-134'].apply(lambda x: np.nan if x == "Non-detect" else x)
df.loc[:, columns] = df.loc[:, columns].map(lambda x: np.nan if x == 'Non-detect' else x)
df.loc[:, columns] = df.loc[:, columns].map(lambda x: np.nan if x == 'ND' else x)

# %%
df.loc[:, ['State', 'Location', 'Sample Type', 'Unit']] = df.loc[:, ['State', 'Location', 'Sample Type', 'Unit']].map(lambda x: x.strip())

# %%
df['Date Posted'] = pd.to_datetime(df['Date Posted'])
df['Date Collected'] = pd.to_datetime(df['Date Collected'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df['Date Posted'] = pd.to_datetime(df['Date Posted'])
#       2 df['Date Collected'] = pd.to_datetime(df['Date Collected'])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# ...

# %%
for col in columns:
    df[col] = pd.to_numeric(df[col])

# %%
df['State'] = df['State'].astype('category')
df['Location'] = df['Location'].astype('category')
df['Unit'] = df['Unit'].astype('category')
df['Sample Type'] = df['Sample Type'].astype('category')

# %%
df.to_csv('radiation_clean.csv', index=False, sep=';', encoding='utf-8')

# %%
df.to_parquet('radiation_clean.prq', index=False)
