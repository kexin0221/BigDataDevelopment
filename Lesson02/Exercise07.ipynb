# %% [markdown]
# ## Exercise 7: Configuring a Title and Labels for Axis Objects

# %%
import scipy

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.set(title="Graph title", xlabel="Label of x axis (units)", ylabel="Label of y axis (units)")
ax.plot()
plt.show()

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# url = "https://raw.githubusercontent.com/TrainingByPackt/Big-Data-Analysis-with-Python/master/Lesson02/Dataset/auto-mpg.data"
df = pd.read_csv("Dataset/auto-mpg.data")
column_names = ['mpg', 'Cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']
df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, delim_whitespace=True)
df.head()
# Out:
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_20284\1221466112.py:11: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, delim_whitespace=True)
#     mpg  Cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0    70
# 1  15.0          8         350.0      165.0  3693.0          11.5    70
# 2  18.0          8         318.0      150.0  3436.0          11.0    70
# 3  16.0          8         304.0      150.0  3433.0          12.0    70
# 4  17.0          8         302.0      140.0  3449.0          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.loc[df.horsepower == '?', 'horsepower'] = np.nan
df['horsepower'] = pd.to_numeric(df['horsepower'])
df['full_date'] = pd.to_datetime(df.year, format='%y')
df['year'] = df['full_date'].dt.year

# %%
fig, ax = plt.subplots()
df.groupby('year')['horsepower'].mean().plot(ax=ax)
ax.legend(['horsepower'])
plt.show()

# %%
import numpy as np
import pandas as pd
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']
df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, delim_whitespace=True)
df.head()
df.loc[df.horsepower == '?', 'horsepower'] = np.nan
df['horsepower'] = pd.to_numeric(df['horsepower'])
df['full_date'] = pd.to_datetime(df.year, format='%y')
df['year'] = df['full_date'].dt.year
df.dtypes
fig, ax = plt.subplots()
df.groupby('year')['horsepower'].mean().plot()
ax.legend(['horsepower'])
plt.show()
# Out:
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_20284\3719872764.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, delim_whitespace=True)

# %%
import numpy as np
import pandas as pd
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']
df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, delim_whitespace=True)
df.head()
df.loc[df.horsepower == '?', 'horsepower'] = np.nan
df['horsepower'] = pd.to_numeric(df['horsepower'])
df['full_date'] = pd.to_datetime(df.year, format='%y')
df['year'] = df['full_date'].dt.year
df.dtypes
df.groupby('year')['horsepower'].mean().plot(ls='-.', color='r', lw=3)
plt.show()
# Out:
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_20284\1059698140.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, delim_whitespace=True)

# %%
fig, ax = plt.subplots()
df.groupby('year')['horsepower'].mean().plot(ax=ax)
ax.legend(['horsepower'])
plt.show()

# %%
import numpy as np
import pandas as pd
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']
df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, delim_whitespace=True)
df.head()
df.loc[df.horsepower == '?', 'horsepower'] = np.nan
df['horsepower'] = pd.to_numeric(df['horsepower'])
df.dtypes
df.plot(kind='scatter', x='weight', y='horsepower', figsize=(20,10))
plt.show()
# Out:
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_20284\1607527959.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, delim_whitespace=True)
