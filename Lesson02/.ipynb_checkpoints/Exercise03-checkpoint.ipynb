# %% [markdown]
# ## Exercise 3: Creating a Graph for a Mathematical Function

# %%
import numpy as np
x = np.linspace(0,100,200)
y = np.sin(x)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()
