# %% [markdown]
# ## Activity 2: Understanding Relationships of Variables Using Scatter Plots

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

url = "Dataset/auto-mpg.data"
df = pd.read_csv(url,sep='\s+')
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_27132\4154678533.py:8: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(url,sep='\s+')

# %%
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']

# %%
df = pd.read_csv(url, names= column_names, sep='\s+')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_27132\2853326468.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(url, names= column_names, sep='\s+')
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0    70
# 1  15.0          8         350.0      165.0  3693.0          11.5    70
# 2  18.0          8         318.0      150.0  3436.0          11.0    70
# 3  16.0          8         304.0      150.0  3433.0          12.0    70
# 4  17.0          8         302.0      140.0  3449.0          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
fig, ax = plt.subplots()
ax.scatter(x = df['horsepower'], y=df['weight'])

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']
df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, sep='\s+')
df.loc[df.horsepower == '?', 'horsepower'] = np.nan
df['horsepower'] = pd.to_numeric(df['horsepower'])
fig, ax = plt.subplots()
ax.scatter(x = df['horsepower'], y=df['weight'])
fig
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_27132\3495755233.py:5: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, sep='\s+')

# %%
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']
df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, sep="\s+")
df.loc[df.horsepower == '?', 'horsepower'] = np.nan
df['horsepower'] = pd.to_numeric(df['horsepower'])
import seaborn as sns
sns.scatterplot(data=df, x='horsepower', y='weight', hue='cylinders', size='mpg')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_27132\3535188684.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, sep="\s+")
# <Axes: xlabel='horsepower', ylabel='weight'>

# %%
import pandas as pd
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']
df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, sep='\s+')
df.loc[df.horsepower == '?', 'horsepower'] = np.nan
df['horsepower'] = pd.to_numeric(df['horsepower'])
df.plot(kind='scatter', x='horsepower', y='weight')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_27132\2580139108.py:3: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, sep='\s+')
# <Axes: xlabel='horsepower', ylabel='weight'>

# %%
import pandas as pd
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']
df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, sep='\s+')
df.loc[df.horsepower == '?', 'horsepower'] = np.nan
df['horsepower'] = pd.to_numeric(df['horsepower'])
fig, ax = plt.subplots()
df.plot(kind='scatter', x='horsepower', y='weight', ax =ax)
plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_27132\253266214.py:3: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("Dataset/auto-mpg.data", names= column_names, sep='\s+')
