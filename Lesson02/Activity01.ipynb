# %% [markdown]
# ## Activity 1: Line Graphs with the Object-Oriented API and Pandas DataFrames

# %%
import pandas as pd

#url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
url = "Dataset/auto-mpg.data"
df = pd.read_csv(url, sep='\s+')
df.head()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_63776\1103766220.py:5: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(url, sep='\s+')
#    18.0  8  307.0  130.0   3504.  12.0  70  1 chevrolet chevelle malibu
# 0  15.0  8  350.0  165.0  3693.0  11.5  70  1         buick skylark 320
# 1  18.0  8  318.0  150.0  3436.0  11.0  70  1        plymouth satellite
# 2  16.0  8  304.0  150.0  3433.0  12.0  70  1             amc rebel sst
# 3  17.0  8  302.0  140.0  3449.0  10.5  70  1               ford torino
# 4  15.0  8  429.0  198.0  4341.0  10.0  70  1          ford galaxie 500

# %%
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']

# %%
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_63776\4199512400.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(url, names= column_names, sep='\s+')
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0    70
# 1  15.0          8         350.0      165.0  3693.0          11.5    70
# 2  18.0          8         318.0      150.0  3436.0          11.0    70
# 3  16.0          8         304.0      150.0  3433.0          12.0    70
# 4  17.0          8         302.0      140.0  3449.0          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.loc[df.horsepower == '?', 'horsepower'] = np.nan
df['horsepower'] = pd.to_numeric(df['horsepower'])
df['full_date'] = pd.to_datetime(df.year, format='%y')
df['year'] = df['full_date'].dt.year
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0  3504.0          12.0  1970
# 1  15.0          8         350.0       165.0  3693.0          11.5  1970
# 2  18.0          8         318.0       150.0  3436.0          11.0  1970
# 3  16.0          8         304.0       150.0  3433.0          12.0  1970
# 4  17.0          8         302.0       140.0  3449.0          10.5  1970
#
#    origin                       name  full_date
# 0       1  chevrolet chevelle malibu 1970-01-01
# 1       1          buick skylark 320 1970-01-01
# 2       1         plymouth satellite 1970-01-01
# 3       1              amc rebel sst 1970-01-01
# 4       1                ford torino 1970-01-01

# %%
df.dtypes
# Out:
# mpg                    float64
# cylinders                int64
# displacement           float64
# horsepower             float64
# weight                 float64
# acceleration           float64
# year                     int32
# origin                   int64
# name                    object
# full_date       datetime64[ns]
# dtype: object

# %%
df.groupby('year')['horsepower'].mean().plot()
# Out:
# <Axes: xlabel='year'>
