# %% [markdown]
# ## Activity 03: Exporting a Graph to a File on Disk

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

url = "Dataset/auto-mpg.data"
df = pd.read_csv(url)

# %%
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']

# %%
df = pd.read_csv(url, names= column_names, delim_whitespace=True)
# Out:
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_27820\1505682265.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(url, names= column_names, delim_whitespace=True)

# %%
fig, ax = plt.subplots()
df.weight.plot(kind='hist', ax=ax)
fig

# %%
fig.savefig('weight_hist.png')
