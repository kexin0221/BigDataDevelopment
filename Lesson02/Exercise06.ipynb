# %% [markdown]
# ## Exercise 6: Analyzing the Behavior of the Number of Cylinders and Horsepower Using a Boxplot

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

url = "Dataset/auto-mpg.data"
df = pd.read_csv(url)

# %%
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']

# %%
df = pd.read_csv(url, names= column_names, delim_whitespace=True)
df.head()
df.loc[df.horsepower == '?', 'horsepower'] = np.nan
df['horsepower'] = pd.to_numeric(df['horsepower'])
df['full_date'] = pd.to_datetime(df.year, format='%y')
df['year'] = df['full_date'].dt.year
# Out:
# C:\Users\MouKexin\AppData\Local\Temp\ipykernel_1764\881762620.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(url, names= column_names, delim_whitespace=True)

# %%
sns.boxplot(data=df, x="cylinders", y="horsepower")
plt.show()

# %%
df.boxplot(column='horsepower', by='cylinders')
plt.show()
