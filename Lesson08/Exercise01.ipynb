# %% [markdown]
# # Exercise 1: Reading Data from a CSV File Using the PySpark Object

# %%
from sqlalchemy.testing import profiling
import ydata

# %%
import seaborn as sns
import time
import re
import os
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="ticks")

# %%
from pyspark.sql import SparkSession
spark = (SparkSession.builder.appName('ml-bank').config("spark.sql.autoBroadcastJoinThreshold", "-1").getOrCreate())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from pyspark.sql import SparkSession
#       2 spark = (SparkSession.builder.appName('ml-bank').config("spark.sql.autoBroadcastJoinThreshold", "-1").getOrCreate())
#
# File C:\spark-3.4.0-bin-without-hadoop\python\pyspark\__init__.py:65
#      63 from pyspark.storagelevel import StorageLevel
#      64 from pyspark.accumulators import Accumulator, AccumulatorParam
# ---> 65 from pyspark.broadcast import Broadcast
#      66 from pyspark.serializers import MarshalSerializer, CPickleSerializer
#      67 from pyspark.taskcontext import TaskContext, BarrierTaskContext, BarrierTaskInfo
#
# File C:\spark-3.4.0-bin-without-hadoop\python\pyspark\broadcast.py:38
#      23 import pickle
#      24 from typing import (
#      25     overload,
#      26     Any,
#    (...)     36     Union,
#      37 )
# ...

# %%
df_csv = spark.read.csv('bank.csv', sep=';', header = True, inferSchema = True)

# %%
df_csv.printSchema()
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- job: string (nullable = true)
#  |-- marital: string (nullable = true)
#  |-- education: string (nullable = true)
#  |-- default: string (nullable = true)
#  |-- balance: integer (nullable = true)
#  |-- housing: string (nullable = true)
#  |-- loan: string (nullable = true)
#  |-- contact: string (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- month: string (nullable = true)
#  |-- duration: integer (nullable = true)
#  |-- campaign: integer (nullable = true)
#  |-- pdays: integer (nullable = true)
#  |-- previous: integer (nullable = true)
#  |-- poutcome: string (nullable = true)
#  |-- y: string (nullable = true)
