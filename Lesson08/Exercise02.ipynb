# %% [markdown]
# ## Exercise 2: Reading Data in PySpark and Carrying Out SQL Operations

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('ml-bank').getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pyspark.sql import SparkSession
#       2 spark = SparkSession.builder.appName('ml-bank').getOrCreate()
#
# File C:\spark-3.4.0-bin-without-hadoop\python\pyspark\__init__.py:65
#      63 from pyspark.storagelevel import StorageLevel
#      64 from pyspark.accumulators import Accumulator, AccumulatorParam
# ---> 65 from pyspark.broadcast import Broadcast
#      66 from pyspark.serializers import MarshalSerializer, CPickleSerializer
#      67 from pyspark.taskcontext import TaskContext, BarrierTaskContext, BarrierTaskInfo
#
# File C:\spark-3.4.0-bin-without-hadoop\python\pyspark\broadcast.py:38
#      23 import pickle
#      24 from typing import (
#      25     overload,
#      26     Any,
#    (...)     36     Union,
#      37 )
# ---> 38 from typing.io import BinaryIO  # type: ignore[import]
#      40 from pyspark.java_gateway import local_connect_and_auth
#      41 from pyspark.serializers import ChunkedStream, pickle_protocol
#
# ModuleNotFoundError: No module named 'typing.io'; 'typing' is not a package

# %%
spark_df = spark.read.csv('bank.csv', sep=';', header = True, inferSchema = True)

# %%
spark_df.head(5)

# %%
spark_df.printSchema()

# %%
spark_df.count()

# %%
len(spark_df.columns), spark_df.columns

# %%
spark_df.select('age','job','marital','education','default','balance','housing','loan', 'contact').describe().show() # revised by zhang

# %%
spark_df.select('day','month','duration','campaign','pdays','previous','poutcome','y').describe().show()

# %%
spark_df.select('balance','y').show(5)

# %%
spark_df.crosstab('y', 'marital').show()

# %%
sample1 = spark_df.sample(False, 0.2, 42)
sample2 = spark_df.sample(False, 0.2, 43)
train = spark_df.sample(False, 0.8, 44)
train.withColumn('balance_new', train.balance /2.0).select('balance','balance_new').show(5)

# %%
train.drop('balance_new')
