# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
url = 'jdbc:mysql://127.0.0.1:3306/sparktest?characterEncoding=utf-8&autoReconnect=true'
# url = 'jdbc:mysql://localhost:3306/sparktest?useUnicode=true&characterEncoding=UTF-8&serverTimezone=UTC'
properties = {'user': 'root', 'password': 'root', 'driver': 'com.mysql.cj.jdbc.Driver'}

# %%
df = spark.read.jdbc(url=url, table='test', properties=properties)

# %%
df.describe
# Out:
# <bound method DataFrame.describe of DataFrame[name: string, age: string, height: string]>

# %%
df.show()
# Out:
# +------+---+------+
# |  name|age|height|
# +------+---+------+
# |  Jonh| 22|  1.80|
# |Hughes| 34|  1.96|
# |  Mary| 27|  1.56|
# +------+---+------+

# %%
spark.stop()
