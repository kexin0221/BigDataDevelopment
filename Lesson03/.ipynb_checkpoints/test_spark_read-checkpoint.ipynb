# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder\
                    .master("local")\
                    .appName("local_test1")\
                    .getOrCreate()

# %%
sdf = spark.read.csv('hdfs://localhost:9000/user/ThinkPad/bank.csv', header=True)

# %%
sdf.show()
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------+
# |"age";"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"|
# +------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                                  30;"unemployed";"...|
# |                                                                                                                                  33;"services";"ma...|
# |                                                                                                                                  35;"management";"...|
# ...
